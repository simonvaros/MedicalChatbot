# %%
import pandas as pd
from math import e

# %%
data = pd.read_csv("./training_log.csv", delimiter=";")

# %%
data.head()
# Out:
#    it_num    loss
# 0     110  8.8969
# 1     120  6.9445
# 2     130  7.0348
# 3     140  6.9664
# 4     150  6.9235

# %%
data.plot.line(y='loss', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv("./latest_training.csv", delimiter=",")

# %%
data.plot.line(y=['Training loss', 'Validation loss'], x='Epoch', figsize=(15,10), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
def countPerplexity(loss):
    return e**loss

# %%
data['Training perplexity'] = data.apply(lambda x: countPerplexity(x['Training loss']), axis=1)
data['Validation perplexity'] = data.apply(lambda x: countPerplexity(x['Validation loss']), axis=1)

# %%
data.plot.line(y=['Training perplexity', 'Validation perplexity'], x='Epoch', figsize=(15,10), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Epoch'>

# %%
data = pd.read_csv('../../training_logs/transformer_log.csv', delimiter=',')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Epoch             16 non-null     int64
#  1    Training loss    16 non-null     float64
#  2    Validation loss  16 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 512.0 bytes

# %%
data['Training perplexity'] = data.apply(lambda x: countPerplexity(x['Training loss']), axis=1)
data['Validation perplexity'] = data.apply(lambda x: countPerplexity(x['Validation loss']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Training loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-4a0eefe45b3f> in <module>
# ----> 1 data['Training perplexity'] = data.apply(lambda x: countPerplexity(x['Training loss']), axis=1)
#       2 data['Validation perplexity'] = data.apply(lambda x: countPerplexity(x['Validation loss']), axis=1)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-5-4a0eefe45b3f> in <lambda>(x)
# ----> 1 data['Training perplexity'] = data.apply(lambda x: countPerplexity(x['Training loss']), axis=1)
#       2 data['Validation perplexity'] = data.apply(lambda x: countPerplexity(x['Validation loss']), axis=1)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Training loss'
